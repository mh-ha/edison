# %%
import pandas as pd

# %%
edison = pd.read_csv('download/edison_diffusion_metrics.csv')
edison
# Out:
#       epoch      loss    step
# 0         0  1.063908      49
# 1         0  1.021241      99
# 2         0  1.057050     149
# 3         1  1.106058     199
# 4         1  1.070079     249
# ...     ...       ...     ...
# 2532    699  0.447829  126649
# 2533    699  0.524255  126699
# 2534    700  0.548824  126749
# 2535    700  0.523620  126799
# 2536    700  0.494939  126849
#
# [2537 rows x 3 columns]

# %%
edison.plot(x='step', y='loss', title='Edison Diffusion Loss')
# Out:
# <Axes: title={'center': 'Edison Diffusion Loss'}, xlabel='step'>

# %%
edison.describe()
# Out:
#              epoch         loss           step
# count  2537.000000  2537.000000    2537.000000
# mean    350.049665     0.637325   63449.000000
# std     202.351250     0.126759   36625.656991
# min       0.000000     0.386003      49.000000
# 25%     175.000000     0.542654   31749.000000
# 50%     350.000000     0.607250   63449.000000
# 75%     525.000000     0.704637   95149.000000
# max     700.000000     1.106058  126849.000000

# %%
ld4lg = pd.read_csv('metrics.csv')

# %%
ld4lg.plot(x='step', y='loss', title='LD4LG Loss')
# Out:
# <Axes: title={'center': 'LD4LG Loss'}, xlabel='step'>

# %%
ld4lg.describe()
# Out:
#              epoch         loss           step
# count  8278.000000  8278.000000    8278.000000
# mean    569.677700     0.384993  206974.000000
# std     329.173215     0.051162  119489.854869
# min       0.000000     0.274157      49.000000
# 25%     285.000000     0.354302  103511.500000
# 50%     570.000000     0.374934  206974.000000
# 75%     855.000000     0.401723  310436.500000
# max    1140.000000     0.921370  413899.000000

# %%
import pandas as pd

ref_data = pd.read_json('../edison/resources/datasets/ROCstory/roc_valid.json', lines=True)

# %%
ref_data.columns = ['text']
ref_data
# Out:
#                                                    text
# 0     The dog jumped up on the bed. I told her to go...
# 1     My family was excited for the fourth of july. ...
# 2     Rally's girlfriend was receiving texts at odd ...
# 3     Jenny knew that the midterm was only a week aw...
# 4     Sally loved to watch TV. She watched a lot of ...
# ...                                                 ...
# 4995  Three friends went to the movies. When they we...
# 4996  Tim wanted to take his wife to Paris. He booke...
# 4997  The man grew out his hair. He saw some gray ha...
# 4998  Nica dared her sister Nola to jump from Sandy ...
# 4999  Karen wanted to go on a trip to France. She st...
#
# [5000 rows x 1 columns]

# %%
ref_data.to_csv('../logs/download/roc_valid.csv', index=False)
